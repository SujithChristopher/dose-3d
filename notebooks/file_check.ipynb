# %%
import numpy as np
from pydicom import dcmread
import os
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
_pth = r"E:\CMC\pyprojects\radio_therapy\dose-3d\dataset\VMAT 2025 - 6. SIB COMPLEX TARGET\T1\873251691"

# %%
# _files

# %%
_files = os.listdir(_pth)

im_size = dcmread(os.path.join(_pth, _files[0]))


for _f in tqdm(_files):
    dcm = dcmread(os.path.join(_pth, _f))
    image = dcm.pixel_array
# Out:
# 180.995244916252
# 181.054959612702
# 181.476944263971
# 182.21209666888
# 183.139001921605
# 184.032728228456
# 184.91816573839
# 185.822845181406
# 186.730510956521
# 187.63883485304
# 188.55313439977
# 189.454826913367
# 190.369121682085
# 191.280436091388
# 192.185112548371
# 193.103061027947
# 194.007739574979
# 194.92203912171
# 195.830361226249
# 196.744661967632
# 197.646355078563
# 198.554017270317
# 199.471965749885
# 200.37664429692
# 201.290938468311
# 202.199266545515
# 203.106932320631
# 204.015257411801
# 204.922921992255
# 205.834235505557
# 206.745549018859
# 207.630317590405
# 208.499831977639
# 209.256883752918
# 210.085588651489
# 210.871170250681
# 211.557226028656
# 212.438344771425
# 213.348996214992
# 214.247040691741
# 215.161337849764
# 216.05639360512
# 216.964059380231
# 217.865752491169
# 218.773412293606
# 219.638281938999
# 220.473294236152
# 221.313277780801
# 222.056397188723
# 222.841977195349
# 223.591728384112
# 224.330863626843
# 225.069998869571
# ...

# %%
dcm.GantryAngle
# Out:
# '178.925135439233'
