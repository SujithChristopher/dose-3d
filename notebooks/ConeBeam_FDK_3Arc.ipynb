# %%
#CT image reconstruct through the FBP algorithm
#Written by Ren-Qi Pan
import math
import os
from pydicom import dcmread, dcmwrite
import pydicom
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
_arc1_pth = r"C:\Users\Pintu\OneDrive - Christian Medical College\Fabricated Phantom Rotational RT\EPID_Rotational Arc plans of Fabricated phantom using Fabricated Phantom\3 ARCS - 7X7"
_arc2_pth = r"C:\Users\Pintu\OneDrive - Christian Medical College\Fabricated Phantom Rotational RT\EPID_Rotational Arc plans of Fabricated phantom using Fabricated Phantom\3 ARCS - 10X10"
_arc3_pth = r"C:\Users\Pintu\OneDrive - Christian Medical College\Fabricated Phantom Rotational RT\EPID_Rotational Arc plans of Fabricated phantom using Fabricated Phantom\3 ARCS - 12X12"

# %%
_files_1 = os.listdir(_arc1_pth)
_files_2 = os.listdir(_arc2_pth)
_files_3 = os.listdir(_arc3_pth)

# %%
dcm = dcmread(os.path.join(_arc1_pth, _files_1[0]))
shape = dcm.Rows, dcm.Columns

# %%
_full_paths_1 = [os.path.join(_arc1_pth, _f) for _f in _files_1]
_full_paths_2 = [os.path.join(_arc2_pth, _f) for _f in _files_2]
_full_paths_3 = [os.path.join(_arc3_pth, _f) for _f in _files_3]

_pth = _full_paths_1 + _full_paths_2 + _full_paths_3

# %%
g_angle = []
_images = np.zeros((len(_pth),shape[0], shape[0]), dtype=np.uint16)
prev = np.zeros((shape[0], shape[0]), dtype=np.uint16)
curr = np.zeros((shape[0], shape[0]), dtype=np.uint16)
_raw_datas = []
for idx, _fname in enumerate(tqdm(_pth)):
    raw = dcmread(_fname)
    curr = raw.pixel_array
    
    _m = curr - prev
    
    if np.max(_m) > 10000:
        _images[idx, :, :] = _images[idx-1, :, :]
        g_angle.append(g_angle[idx-1])
    else:
        _images[idx, :, :] = curr - prev
        prev = curr
        g_angle.append(raw.GantryAngle)
        
    prev = curr
# Out:
# 100%|██████████| 1194/1194 [00:09<00:00, 125.32it/s]

# %%
g_angle = np.array(g_angle)
sorted_inx = np.argsort(g_angle)

sorted_images = np.zeros((len(_pth),shape[0], shape[0]), dtype=np.uint16)

for idx, val in enumerate(tqdm(sorted_inx)):
    sorted_images[idx, :, :] = _images[val, :, :]
# Out:
# 100%|██████████| 1194/1194 [00:09<00:00, 121.48it/s]

# %%
g_angle2 = g_angle[sorted_inx]
_images = []

# %%
#define the filter function: Ram-Lak (R-L) filter and the Shepp-Logan(S-L) filter
#N:number of detector cells
#d: step width of detector cells
PI=math.pi

def filter_SL(N,d):
    fh_SL=np.zeros(N)
    for k1 in range(0,N,1):
        fh_SL[k1]=-2.0/(PI*PI*d*d*(4*(k1-N/2.0)**2-1))
    return fh_SL

def nearestPowerOf2(N):
    # Calculate log2 of N
    a = int(math.log2(N))
    if 2**a == N:
        return N
    return 2**(a + 1)

# %%
from scipy.fft import fft, ifft

def Fun_Weigth_Projection(projection_beta,SOD,delta_dd):
    Nrows,Ncolumns=projection_beta.shape
    dd_column=delta_dd*np.arange(-Ncolumns/2+0.5,(Ncolumns/2+1)-0.5,1.0)#coordinate of detector cell in horizontal 
    dd_row=delta_dd*np.arange(-Nrows/2+0.5,(Nrows/2+1)-0.5,1.0)#coordinate of detector cell in vertical
    dd_row2D,dd_column2D=np.meshgrid(dd_row,dd_column,indexing='ij')
    weighted_projection=projection_beta*SOD/np.sqrt(SOD*SOD+np.power(dd_row2D,2.0)+np.power(dd_column2D,2.0))
    return weighted_projection

def optimize_convolution(weighted_projection, fh_RL):
    Nrows, Ncolumns = weighted_projection.shape
    Nfft = nearestPowerOf2(2 * Ncolumns - 1)
    fh_RL_padded = np.zeros(Nfft)
    fh_RL_padded[:len(fh_RL)] = fh_RL / 2.0  # Scale and pad filter response
    
    fh_RL_fft = fft(fh_RL_padded)  # FFT of the filter response
    
    # Zero pad the input projection for FFT
    projection_padded = np.zeros((Nrows, Nfft))
    projection_padded[:, :Ncolumns] = weighted_projection

    # Perform FFT on each row of the projection
    projection_fft = fft(projection_padded, axis=1)
    
    # Element-wise multiplication in the frequency domain
    convoluted_freq = projection_fft * fh_RL_fft
    
    # Perform the inverse FFT to get back to the time domain
    convoluted_time = ifft(convoluted_freq, axis=1).real
    
    # Slice to obtain the result with the correct dimensions
    filtered_projection = convoluted_time[:, :Ncolumns]
    
    return filtered_projection


def Fun_Filter_Projection(weighted_projection,fh_RL):
    Nrows,Ncolumns=weighted_projection.shape
    Nfft=nearestPowerOf2(2*Ncolumns-1)
    filtered_projection=np.zeros((Nrows,Ncolumns))
    for row in range(Nrows):
        projection_row=weighted_projection[row,:]
        zeros_pad=np.zeros(Nfft-Ncolumns)
        projection_row=np.concatenate((projection_row,zeros_pad))
        convoluted_time=np.convolve(projection_row,fh_RL/2.0,mode='same')
        convoluted_time=convoluted_time[:Ncolumns]
        filtered_projection[row,:]=convoluted_time
    return filtered_projection

def Fun_BackProjection(filtered_projection,SOD,beta_num,beta_m,delta_dd,Nimage):
    Nrows,Ncolumns=filtered_projection.shape
    MX, MZ=Nimage,int(Nimage*Nrows/Ncolumns)
    #roi[0], roi[1]: the min and max of x-axis and y-axis
    #roi[2],roi[3]: the min and max of z-axis
    
    roi=delta_dd*np.array([-Ncolumns/2.0+0.5,Ncolumns/2.0-0.5,-Nrows/2.0+0.5,Nrows/2.0-0.5])
    hx=(roi[1]-roi[0])/(MX-1) #interval of x-axis and y-axis
    xrange=roi[0]+hx*np.arange(0,MX) #coordinate vector of x-axis and y-axis 
    hy=(roi[3]-roi[2])/(MZ-1) #interval of z-axis
    yrange=roi[2]+hy*np.arange(0,MZ) #coordinate vector of z-axis 
    XX,YY,ZZ=np.meshgrid(xrange,xrange,yrange,indexing='ij')
    temp_rec=np.zeros((MX,MX,MZ)) #store back projection contribution
    U=(SOD+XX*np.sin(beta_m)-YY*np.cos(beta_m))/SOD
    a=(XX*np.cos(beta_m)+YY*np.sin(beta_m))/U
    xx=np.int32(np.floor(a/delta_dd)) #beam numbering,strart from -Ncolumns/2
    u1=a/delta_dd-xx  #the decimal part of a
    b=ZZ/U
    yy=np.int32(np.floor(b/delta_dd)) #beam numbering,strart from -Nrows/2
    u2=b/delta_dd-yy #the decimal part of b
    xx=xx+int(Ncolumns/2) #numbering from 0
    yy=yy+int(Nrows/2) #numbering from 0

    mask=np.where((xx >=0) & (xx< Ncolumns-1) & (yy >=0) & (yy<Nrows-1))
    xx=xx[mask]
    yy=yy[mask]
    u1=u1[mask]
    u2=u2[mask]
    # print(mask)
    temp=(1-u1)*(1-u2)*filtered_projection[yy,xx]+(1-u1)*u2*filtered_projection[yy+1,xx]+\
                 (1-u2)*u1*filtered_projection[yy,xx+1]+u1*u2*filtered_projection[yy+1,xx+1]
    temp_rec[mask]=temp_rec[mask]+temp/(np.power(U[mask],2))*2*PI/beta_num
    print('backprojection, beta: ',round(beta_m*180/PI,1))
    return temp_rec

# %%
def ConeBeam_FDK_Backprojection(projection,fh_RL,beta,SOD,Nimage,delta_dd):
    # projection: projection data in 3D, (angle,row, colums)
    # fh_RL: R-L filter function
    # beta: rotate angles in degrees
    # SOD: source to rotation center distance in mm unit
    # delta_dd: interval of the virtual detector cell
    Ncolumns=projection.shape[2]
    Nrows=projection.shape[1]
    rec_image=np.zeros((Nimage,Nimage,int(Nimage*Nrows/Ncolumns)))
    beta_num=len(beta) #number of angles
    beta=beta*PI/180.0 # view angle in radian
    for m in range(0, beta_num,1):
        projection_beta=projection[m,:,:] #projection matrix at the beta angle
        weighted_projection=Fun_Weigth_Projection(projection_beta,SOD,delta_dd)
        filtered_projection=optimize_convolution(weighted_projection,fh_RL)
        rec_image=rec_image+Fun_BackProjection(weighted_projection,SOD,beta_num,beta[m],delta_dd,Nimage)
        # break
    return rec_image

# %%
sorted_images.shape
# Out:
# (1194, 1190, 1190)

# %%
Ncolumns = sorted_images.shape[2]

# %%
SID = dcm.RTImageSID
SAD = dcm.RadiationMachineSAD

# %%
Nimage=100 #size of image
beta=g_angle2 #rotate(view) angles
SOD=SAD#source to origin distance, in unit mm
SDD=SID #source to center of detector, in unit mm
width=0.172 #size of detector cell, in unit mm
delta_dd=width*SOD/SDD #interval of the virtual detector cell
Nfft=nearestPowerOf2(2*Ncolumns-1) #number of points for FFT
fh_RL=filter_SL(Nfft,delta_dd)  #get the filter kernel function
#reconstruct the scanned object through the FBP algorithm
rec_image=ConeBeam_FDK_Backprojection(sorted_images,fh_RL,beta,SOD,Nimage,delta_dd)
# Out:
# backprojection, beta:  0.4
# backprojection, beta:  0.5
# backprojection, beta:  0.8
# backprojection, beta:  1.3
# backprojection, beta:  1.4
# backprojection, beta:  1.7
# backprojection, beta:  2.2
# backprojection, beta:  2.3
# backprojection, beta:  2.6
# backprojection, beta:  3.1
# backprojection, beta:  3.2
# backprojection, beta:  3.5
# backprojection, beta:  4.0
# backprojection, beta:  4.2
# backprojection, beta:  4.4
# backprojection, beta:  4.4
# backprojection, beta:  4.9
# backprojection, beta:  5.1
# backprojection, beta:  5.8
# backprojection, beta:  5.8
# backprojection, beta:  6.0
# backprojection, beta:  6.0
# backprojection, beta:  6.2
# backprojection, beta:  7.1
# backprojection, beta:  7.7
# backprojection, beta:  7.8
# backprojection, beta:  8.0
# backprojection, beta:  8.6
# backprojection, beta:  8.7
# backprojection, beta:  8.9
# backprojection, beta:  9.5
# backprojection, beta:  9.6
# backprojection, beta:  9.9
# backprojection, beta:  10.4
# backprojection, beta:  10.5
# backprojection, beta:  10.8
# backprojection, beta:  11.3
# backprojection, beta:  11.4
# backprojection, beta:  11.7
# backprojection, beta:  12.2
# backprojection, beta:  12.3
# backprojection, beta:  12.6
# backprojection, beta:  13.1
# backprojection, beta:  13.3
# backprojection, beta:  13.5
# backprojection, beta:  14.0
# backprojection, beta:  14.2
# backprojection, beta:  14.4
# backprojection, beta:  14.9
# backprojection, beta:  15.1
# backprojection, beta:  15.3
# backprojection, beta:  15.9
# backprojection, beta:  16.0
# backprojection, beta:  16.2
# backprojection, beta:  16.8
# backprojection, beta:  16.9
# backprojection, beta:  17.1
# backprojection, beta:  17.7
# backprojection, beta:  17.8
# backprojection, beta:  18.0
# backprojection, beta:  18.6
# backprojection, beta:  18.7
# backprojection, beta:  19.0
# backprojection, beta:  19.5
# backprojection, beta:  19.6
# backprojection, beta:  19.9
# backprojection, beta:  20.4
# backprojection, beta:  20.5
# backprojection, beta:  20.8
# backprojection, beta:  21.3
# backprojection, beta:  21.4
# backprojection, beta:  21.7
# backprojection, beta:  22.2
# backprojection, beta:  22.3
# backprojection, beta:  22.6
# backprojection, beta:  23.1
# backprojection, beta:  23.3
# backprojection, beta:  23.5
# backprojection, beta:  24.0
# backprojection, beta:  24.2
# backprojection, beta:  24.4
# backprojection, beta:  24.9
# backprojection, beta:  25.1
# backprojection, beta:  25.3
# backprojection, beta:  25.8
# backprojection, beta:  26.0
# backprojection, beta:  26.2
# backprojection, beta:  26.8
# backprojection, beta:  26.9
# backprojection, beta:  27.1
# backprojection, beta:  27.7
# backprojection, beta:  27.8
# backprojection, beta:  28.0
# backprojection, beta:  28.6
# backprojection, beta:  28.7
# backprojection, beta:  29.0
# backprojection, beta:  29.5
# backprojection, beta:  29.6
# backprojection, beta:  29.9
# backprojection, beta:  30.4
# backprojection, beta:  30.5
# backprojection, beta:  30.8
# backprojection, beta:  31.3
# backprojection, beta:  31.4
# backprojection, beta:  31.7
# backprojection, beta:  32.2
# backprojection, beta:  32.3
# backprojection, beta:  32.6
# backprojection, beta:  33.1
# backprojection, beta:  33.3
# backprojection, beta:  33.5
# backprojection, beta:  34.0
# backprojection, beta:  34.2
# backprojection, beta:  34.4
# backprojection, beta:  34.9
# backprojection, beta:  35.1
# backprojection, beta:  35.3
# backprojection, beta:  35.8
# backprojection, beta:  36.0
# backprojection, beta:  36.2
# backprojection, beta:  36.8
# backprojection, beta:  36.9
# backprojection, beta:  37.1
# backprojection, beta:  37.7
# backprojection, beta:  37.8
# backprojection, beta:  38.0
# backprojection, beta:  38.6
# backprojection, beta:  38.7
# backprojection, beta:  39.0
# backprojection, beta:  39.5
# backprojection, beta:  39.6
# backprojection, beta:  39.9
# backprojection, beta:  40.4
# backprojection, beta:  40.5
# backprojection, beta:  40.8
# backprojection, beta:  41.3
# backprojection, beta:  41.4
# backprojection, beta:  41.7
# backprojection, beta:  42.2
# backprojection, beta:  42.3
# backprojection, beta:  42.6
# backprojection, beta:  43.1
# backprojection, beta:  43.3
# backprojection, beta:  43.5
# backprojection, beta:  44.0
# backprojection, beta:  44.2
# backprojection, beta:  44.4
# backprojection, beta:  44.9
# backprojection, beta:  45.1
# backprojection, beta:  45.3
# backprojection, beta:  45.9
# backprojection, beta:  46.0
# backprojection, beta:  46.2
# backprojection, beta:  46.8
# backprojection, beta:  46.9
# backprojection, beta:  47.1
# backprojection, beta:  47.7
# backprojection, beta:  47.8
# backprojection, beta:  48.1
# backprojection, beta:  48.6
# backprojection, beta:  48.7
# backprojection, beta:  49.0
# backprojection, beta:  49.5
# backprojection, beta:  49.6
# backprojection, beta:  49.9
# backprojection, beta:  50.4
# backprojection, beta:  50.5
# backprojection, beta:  50.8
# backprojection, beta:  51.3
# backprojection, beta:  51.4
# backprojection, beta:  51.7
# backprojection, beta:  52.2
# backprojection, beta:  52.4
# backprojection, beta:  52.6
# backprojection, beta:  53.1
# backprojection, beta:  53.3
# backprojection, beta:  53.5
# backprojection, beta:  54.0
# backprojection, beta:  54.2
# backprojection, beta:  54.4
# backprojection, beta:  54.9
# backprojection, beta:  55.1
# backprojection, beta:  55.3
# backprojection, beta:  55.9
# backprojection, beta:  56.0
# backprojection, beta:  56.2
# backprojection, beta:  56.8
# backprojection, beta:  56.9
# backprojection, beta:  57.1
# backprojection, beta:  57.7
# backprojection, beta:  57.8
# backprojection, beta:  58.1
# backprojection, beta:  58.6
# backprojection, beta:  58.7
# backprojection, beta:  59.0
# backprojection, beta:  59.5
# backprojection, beta:  59.6
# backprojection, beta:  59.9
# backprojection, beta:  60.4
# backprojection, beta:  60.5
# backprojection, beta:  60.8
# backprojection, beta:  61.3
# backprojection, beta:  61.4
# backprojection, beta:  61.7
# backprojection, beta:  62.2
# backprojection, beta:  62.4
# backprojection, beta:  62.6
# backprojection, beta:  63.1
# backprojection, beta:  63.3
# backprojection, beta:  63.5
# backprojection, beta:  64.0
# backprojection, beta:  64.2
# backprojection, beta:  64.4
# backprojection, beta:  65.0
# backprojection, beta:  65.1
# backprojection, beta:  65.3
# backprojection, beta:  65.9
# backprojection, beta:  66.0
# backprojection, beta:  66.2
# backprojection, beta:  66.8
# backprojection, beta:  66.9
# backprojection, beta:  67.1
# backprojection, beta:  67.7
# backprojection, beta:  67.8
# backprojection, beta:  68.1
# backprojection, beta:  68.6
# backprojection, beta:  68.7
# backprojection, beta:  69.0
# backprojection, beta:  69.5
# backprojection, beta:  69.6
# backprojection, beta:  69.9
# backprojection, beta:  70.4
# backprojection, beta:  70.5
# backprojection, beta:  70.8
# backprojection, beta:  71.3
# backprojection, beta:  71.4
# backprojection, beta:  71.7
# backprojection, beta:  72.2
# backprojection, beta:  72.4
# backprojection, beta:  72.6
# backprojection, beta:  73.1
# backprojection, beta:  73.3
# backprojection, beta:  73.5
# backprojection, beta:  74.0
# backprojection, beta:  74.2
# backprojection, beta:  74.4
# backprojection, beta:  75.0
# backprojection, beta:  75.1
# backprojection, beta:  75.3
# backprojection, beta:  75.9
# backprojection, beta:  76.0
# backprojection, beta:  76.2
# backprojection, beta:  76.8
# backprojection, beta:  76.9
# backprojection, beta:  77.1
# backprojection, beta:  77.7
# backprojection, beta:  77.8
# backprojection, beta:  78.1
# backprojection, beta:  78.6
# backprojection, beta:  78.7
# backprojection, beta:  79.0
# backprojection, beta:  79.5
# backprojection, beta:  79.6
# backprojection, beta:  79.9
# backprojection, beta:  80.4
# backprojection, beta:  80.5
# backprojection, beta:  80.8
# backprojection, beta:  81.3
# backprojection, beta:  81.5
# backprojection, beta:  81.7
# backprojection, beta:  82.2
# backprojection, beta:  82.4
# backprojection, beta:  82.6
# backprojection, beta:  83.1
# backprojection, beta:  83.3
# backprojection, beta:  83.5
# backprojection, beta:  84.0
# backprojection, beta:  84.2
# backprojection, beta:  84.4
# backprojection, beta:  85.0
# backprojection, beta:  85.1
# backprojection, beta:  85.3
# backprojection, beta:  85.9
# backprojection, beta:  86.0
# backprojection, beta:  86.2
# backprojection, beta:  86.8
# backprojection, beta:  86.9
# backprojection, beta:  87.1
# backprojection, beta:  87.7
# backprojection, beta:  87.8
# backprojection, beta:  88.1
# backprojection, beta:  88.6
# backprojection, beta:  88.7
# backprojection, beta:  89.0
# backprojection, beta:  89.5
# backprojection, beta:  89.6
# backprojection, beta:  89.9
# backprojection, beta:  90.4
# backprojection, beta:  90.5
# backprojection, beta:  90.8
# backprojection, beta:  91.3
# backprojection, beta:  91.4
# backprojection, beta:  91.7
# backprojection, beta:  92.2
# backprojection, beta:  92.4
# backprojection, beta:  92.6
# backprojection, beta:  93.1
# backprojection, beta:  93.3
# backprojection, beta:  93.5
# backprojection, beta:  94.0
# backprojection, beta:  94.2
# backprojection, beta:  94.4
# backprojection, beta:  95.0
# backprojection, beta:  95.1
# backprojection, beta:  95.3
# backprojection, beta:  95.9
# backprojection, beta:  96.0
# backprojection, beta:  96.2
# backprojection, beta:  96.8
# backprojection, beta:  96.9
# backprojection, beta:  97.1
# backprojection, beta:  97.7
# backprojection, beta:  97.8
# backprojection, beta:  98.1
# backprojection, beta:  98.6
# backprojection, beta:  98.7
# backprojection, beta:  99.0
# backprojection, beta:  99.5
# backprojection, beta:  99.6
# backprojection, beta:  99.9
# backprojection, beta:  100.4
# backprojection, beta:  100.5
# backprojection, beta:  100.8
# backprojection, beta:  101.3
# backprojection, beta:  101.5
# backprojection, beta:  101.7
# backprojection, beta:  102.2
# backprojection, beta:  102.4
# backprojection, beta:  102.6
# backprojection, beta:  103.1
# backprojection, beta:  103.3
# backprojection, beta:  103.5
# backprojection, beta:  104.0
# backprojection, beta:  104.2
# backprojection, beta:  104.4
# backprojection, beta:  105.0
# backprojection, beta:  105.1
# backprojection, beta:  105.3
# backprojection, beta:  105.9
# backprojection, beta:  106.0
# backprojection, beta:  106.2
# backprojection, beta:  106.8
# backprojection, beta:  106.9
# backprojection, beta:  107.2
# backprojection, beta:  107.7
# backprojection, beta:  107.8
# backprojection, beta:  108.1
# backprojection, beta:  108.6
# backprojection, beta:  108.7
# backprojection, beta:  109.0
# backprojection, beta:  109.5
# backprojection, beta:  109.6
# backprojection, beta:  109.9
# backprojection, beta:  110.4
# backprojection, beta:  110.5
# backprojection, beta:  110.8
# backprojection, beta:  111.3
# backprojection, beta:  111.5
# backprojection, beta:  111.7
# backprojection, beta:  112.2
# backprojection, beta:  112.4
# backprojection, beta:  112.6
# backprojection, beta:  113.1
# backprojection, beta:  113.3
# backprojection, beta:  113.5
# backprojection, beta:  114.0
# backprojection, beta:  114.2
# backprojection, beta:  114.4
# backprojection, beta:  115.0
# backprojection, beta:  115.1
# backprojection, beta:  115.3
# backprojection, beta:  115.9
# backprojection, beta:  116.0
# backprojection, beta:  116.2
# backprojection, beta:  116.8
# backprojection, beta:  116.9
# backprojection, beta:  117.2
# backprojection, beta:  117.7
# backprojection, beta:  117.8
# backprojection, beta:  118.1
# backprojection, beta:  118.6
# backprojection, beta:  118.7
# backprojection, beta:  119.0
# backprojection, beta:  119.5
# backprojection, beta:  119.6
# backprojection, beta:  119.9
# backprojection, beta:  120.4
# backprojection, beta:  120.5
# backprojection, beta:  120.8
# backprojection, beta:  121.3
# backprojection, beta:  121.4
# backprojection, beta:  121.7
# backprojection, beta:  122.2
# backprojection, beta:  122.4
# backprojection, beta:  122.6
# backprojection, beta:  123.1
# backprojection, beta:  123.3
# backprojection, beta:  123.5
# backprojection, beta:  124.0
# backprojection, beta:  124.2
# backprojection, beta:  124.4
# backprojection, beta:  124.9
# backprojection, beta:  125.1
# backprojection, beta:  125.3
# backprojection, beta:  125.9
# backprojection, beta:  126.0
# backprojection, beta:  126.2
# backprojection, beta:  126.8
# backprojection, beta:  126.9
# backprojection, beta:  127.1
# backprojection, beta:  127.7
# backprojection, beta:  127.8
# backprojection, beta:  128.1
# backprojection, beta:  128.6
# backprojection, beta:  128.7
# backprojection, beta:  129.0
# backprojection, beta:  129.5
# backprojection, beta:  129.6
# backprojection, beta:  129.9
# backprojection, beta:  130.4
# backprojection, beta:  130.5
# backprojection, beta:  130.8
# backprojection, beta:  131.3
# backprojection, beta:  131.4
# backprojection, beta:  131.7
# backprojection, beta:  132.2
# backprojection, beta:  132.4
# backprojection, beta:  132.6
# backprojection, beta:  133.1
# backprojection, beta:  133.3
# backprojection, beta:  133.5
# backprojection, beta:  134.0
# backprojection, beta:  134.2
# backprojection, beta:  134.4
# backprojection, beta:  134.9
# backprojection, beta:  135.1
# backprojection, beta:  135.3
# backprojection, beta:  135.9
# backprojection, beta:  136.0
# backprojection, beta:  136.2
# backprojection, beta:  136.8
# backprojection, beta:  136.9
# backprojection, beta:  137.1
# backprojection, beta:  137.7
# backprojection, beta:  137.8
# backprojection, beta:  138.0
# backprojection, beta:  138.6
# backprojection, beta:  138.7
# backprojection, beta:  139.0
# backprojection, beta:  139.5
# backprojection, beta:  139.6
# backprojection, beta:  139.9
# backprojection, beta:  140.4
# backprojection, beta:  140.5
# backprojection, beta:  140.8
# backprojection, beta:  141.3
# backprojection, beta:  141.4
# backprojection, beta:  141.7
# backprojection, beta:  142.2
# backprojection, beta:  142.3
# backprojection, beta:  142.6
# backprojection, beta:  143.1
# backprojection, beta:  143.3
# backprojection, beta:  143.5
# backprojection, beta:  144.0
# backprojection, beta:  144.2
# backprojection, beta:  144.4
# backprojection, beta:  144.9
# backprojection, beta:  145.1
# backprojection, beta:  145.3
# backprojection, beta:  145.8
# backprojection, beta:  146.0
# backprojection, beta:  146.2
# backprojection, beta:  146.8
# backprojection, beta:  146.9
# backprojection, beta:  147.1
# backprojection, beta:  147.7
# backprojection, beta:  147.8
# backprojection, beta:  148.0
# backprojection, beta:  148.6
# backprojection, beta:  148.7
# backprojection, beta:  149.0
# backprojection, beta:  149.5
# backprojection, beta:  149.6
# backprojection, beta:  149.9
# backprojection, beta:  150.4
# backprojection, beta:  150.5
# backprojection, beta:  150.8
# backprojection, beta:  151.3
# backprojection, beta:  151.4
# backprojection, beta:  151.7
# backprojection, beta:  152.2
# backprojection, beta:  152.3
# backprojection, beta:  152.6
# backprojection, beta:  153.1
# backprojection, beta:  153.3
# backprojection, beta:  153.5
# backprojection, beta:  154.0
# backprojection, beta:  154.2
# backprojection, beta:  154.4
# backprojection, beta:  154.9
# backprojection, beta:  155.1
# backprojection, beta:  155.3
# backprojection, beta:  155.9
# backprojection, beta:  156.0
# backprojection, beta:  156.2
# backprojection, beta:  156.8
# backprojection, beta:  156.9
# backprojection, beta:  157.1
# backprojection, beta:  157.7
# backprojection, beta:  157.8
# backprojection, beta:  158.0
# backprojection, beta:  158.6
# backprojection, beta:  158.7
# backprojection, beta:  159.0
# backprojection, beta:  159.5
# backprojection, beta:  159.6
# backprojection, beta:  159.9
# backprojection, beta:  160.4
# backprojection, beta:  160.5
# backprojection, beta:  160.8
# backprojection, beta:  161.3
# backprojection, beta:  161.4
# backprojection, beta:  161.7
# backprojection, beta:  162.2
# backprojection, beta:  162.3
# backprojection, beta:  162.6
# backprojection, beta:  163.1
# backprojection, beta:  163.3
# backprojection, beta:  163.5
# backprojection, beta:  164.0
# backprojection, beta:  164.2
# backprojection, beta:  164.4
# backprojection, beta:  164.9
# backprojection, beta:  165.1
# backprojection, beta:  165.3
# backprojection, beta:  165.9
# backprojection, beta:  166.0
# backprojection, beta:  166.2
# backprojection, beta:  166.8
# backprojection, beta:  166.9
# backprojection, beta:  167.1
# backprojection, beta:  167.7
# backprojection, beta:  167.8
# backprojection, beta:  168.0
# backprojection, beta:  168.6
# backprojection, beta:  168.7
# backprojection, beta:  169.0
# backprojection, beta:  169.5
# backprojection, beta:  169.6
# backprojection, beta:  169.9
# backprojection, beta:  170.4
# backprojection, beta:  170.5
# backprojection, beta:  170.8
# backprojection, beta:  171.3
# backprojection, beta:  171.4
# backprojection, beta:  171.7
# backprojection, beta:  172.2
# backprojection, beta:  172.3
# backprojection, beta:  172.6
# backprojection, beta:  173.1
# backprojection, beta:  173.3
# backprojection, beta:  173.5
# backprojection, beta:  174.0
# backprojection, beta:  174.2
# backprojection, beta:  174.4
# backprojection, beta:  174.9
# backprojection, beta:  175.1
# backprojection, beta:  175.3
# backprojection, beta:  175.9
# backprojection, beta:  176.0
# backprojection, beta:  176.2
# backprojection, beta:  176.8
# backprojection, beta:  176.9
# backprojection, beta:  177.1
# backprojection, beta:  177.7
# backprojection, beta:  177.8
# backprojection, beta:  178.0
# backprojection, beta:  178.4
# backprojection, beta:  178.5
# backprojection, beta:  178.6
# backprojection, beta:  178.8
# backprojection, beta:  178.8
# backprojection, beta:  178.9
# backprojection, beta:  178.9
# backprojection, beta:  178.9
# backprojection, beta:  178.9
# backprojection, beta:  178.9
# backprojection, beta:  178.9
# backprojection, beta:  181.0
# backprojection, beta:  181.0
# backprojection, beta:  181.1
# backprojection, beta:  181.2
# backprojection, beta:  181.4
# backprojection, beta:  181.5
# backprojection, beta:  181.7
# backprojection, beta:  182.2
# backprojection, beta:  182.3
# backprojection, beta:  182.5
# backprojection, beta:  183.1
# backprojection, beta:  183.2
# backprojection, beta:  183.5
# backprojection, beta:  184.0
# backprojection, beta:  184.1
# backprojection, beta:  184.4
# backprojection, beta:  184.9
# backprojection, beta:  185.0
# backprojection, beta:  185.2
# backprojection, beta:  185.8
# backprojection, beta:  185.9
# backprojection, beta:  186.2
# backprojection, beta:  186.7
# backprojection, beta:  186.8
# backprojection, beta:  187.1
# backprojection, beta:  187.6
# backprojection, beta:  187.7
# backprojection, beta:  188.0
# backprojection, beta:  188.5
# backprojection, beta:  188.6
# backprojection, beta:  188.9
# backprojection, beta:  189.4
# backprojection, beta:  189.5
# backprojection, beta:  189.8
# backprojection, beta:  190.3
# backprojection, beta:  190.5
# backprojection, beta:  190.7
# backprojection, beta:  191.2
# backprojection, beta:  191.4
# backprojection, beta:  191.6
# backprojection, beta:  192.1
# backprojection, beta:  192.3
# backprojection, beta:  192.5
# backprojection, beta:  193.1
# backprojection, beta:  193.2
# backprojection, beta:  193.4
# backprojection, beta:  194.0
# backprojection, beta:  194.1
# backprojection, beta:  194.3
# backprojection, beta:  194.9
# backprojection, beta:  195.0
# backprojection, beta:  195.2
# backprojection, beta:  195.8
# backprojection, beta:  195.9
# backprojection, beta:  196.2
# backprojection, beta:  196.7
# backprojection, beta:  196.8
# backprojection, beta:  197.1
# backprojection, beta:  197.6
# backprojection, beta:  197.7
# backprojection, beta:  198.0
# backprojection, beta:  198.5
# backprojection, beta:  198.6
# backprojection, beta:  198.9
# backprojection, beta:  199.4
# backprojection, beta:  199.6
# backprojection, beta:  199.8
# backprojection, beta:  200.3
# backprojection, beta:  200.5
# backprojection, beta:  200.7
# backprojection, beta:  201.2
# backprojection, beta:  201.4
# backprojection, beta:  201.6
# backprojection, beta:  202.1
# backprojection, beta:  202.3
# backprojection, beta:  202.5
# backprojection, beta:  203.1
# backprojection, beta:  203.2
# backprojection, beta:  203.4
# backprojection, beta:  204.0
# backprojection, beta:  204.1
# backprojection, beta:  204.3
# backprojection, beta:  204.9
# backprojection, beta:  205.0
# backprojection, beta:  205.3
# backprojection, beta:  205.8
# backprojection, beta:  205.9
# backprojection, beta:  206.2
# backprojection, beta:  206.7
# backprojection, beta:  206.8
# backprojection, beta:  207.1
# backprojection, beta:  207.6
# backprojection, beta:  207.7
# backprojection, beta:  208.0
# backprojection, beta:  208.5
# backprojection, beta:  208.6
# backprojection, beta:  208.9
# backprojection, beta:  209.4
# backprojection, beta:  209.6
# backprojection, beta:  209.8
# backprojection, beta:  210.3
# backprojection, beta:  210.5
# backprojection, beta:  210.7
# backprojection, beta:  211.2
# backprojection, beta:  211.4
# backprojection, beta:  211.6
# backprojection, beta:  212.1
# backprojection, beta:  212.3
# backprojection, beta:  212.5
# backprojection, beta:  213.1
# backprojection, beta:  213.2
# backprojection, beta:  213.4
# backprojection, beta:  214.0
# backprojection, beta:  214.1
# backprojection, beta:  214.3
# backprojection, beta:  214.9
# backprojection, beta:  215.0
# backprojection, beta:  215.3
# backprojection, beta:  215.8
# backprojection, beta:  215.9
# backprojection, beta:  216.2
# backprojection, beta:  216.7
# backprojection, beta:  216.8
# backprojection, beta:  217.1
# backprojection, beta:  217.6
# backprojection, beta:  217.7
# backprojection, beta:  218.0
# backprojection, beta:  218.5
# backprojection, beta:  218.7
# backprojection, beta:  218.9
# backprojection, beta:  219.4
# backprojection, beta:  219.6
# backprojection, beta:  219.8
# backprojection, beta:  220.3
# backprojection, beta:  220.5
# backprojection, beta:  220.7
# backprojection, beta:  221.2
# backprojection, beta:  221.4
# backprojection, beta:  221.6
# backprojection, beta:  222.2
# backprojection, beta:  222.3
# backprojection, beta:  222.5
# backprojection, beta:  223.1
# backprojection, beta:  223.2
# backprojection, beta:  223.4
# backprojection, beta:  224.0
# backprojection, beta:  224.1
# backprojection, beta:  224.4
# backprojection, beta:  224.9
# backprojection, beta:  225.0
# backprojection, beta:  225.3
# backprojection, beta:  225.8
# backprojection, beta:  225.9
# backprojection, beta:  226.2
# backprojection, beta:  226.7
# backprojection, beta:  226.8
# backprojection, beta:  227.1
# backprojection, beta:  227.6
# backprojection, beta:  227.7
# backprojection, beta:  228.0
# backprojection, beta:  228.5
# backprojection, beta:  228.7
# backprojection, beta:  228.9
# backprojection, beta:  229.4
# backprojection, beta:  229.6
# backprojection, beta:  229.8
# backprojection, beta:  230.3
# backprojection, beta:  230.5
# backprojection, beta:  230.7
# backprojection, beta:  231.2
# backprojection, beta:  231.4
# backprojection, beta:  231.6
# backprojection, beta:  232.2
# backprojection, beta:  232.3
# backprojection, beta:  232.5
# backprojection, beta:  233.1
# backprojection, beta:  233.2
# backprojection, beta:  233.4
# backprojection, beta:  234.0
# backprojection, beta:  234.1
# backprojection, beta:  234.4
# backprojection, beta:  234.9
# backprojection, beta:  235.0
# backprojection, beta:  235.3
# backprojection, beta:  235.8
# backprojection, beta:  235.9
# backprojection, beta:  236.2
# backprojection, beta:  236.7
# backprojection, beta:  236.8
# backprojection, beta:  237.1
# backprojection, beta:  237.6
# backprojection, beta:  237.7
# backprojection, beta:  238.0
# backprojection, beta:  238.5
# backprojection, beta:  238.6
# backprojection, beta:  238.9
# backprojection, beta:  239.4
# backprojection, beta:  239.6
# backprojection, beta:  239.8
# backprojection, beta:  240.3
# backprojection, beta:  240.5
# backprojection, beta:  240.7
# backprojection, beta:  241.2
# backprojection, beta:  241.4
# backprojection, beta:  241.6
# backprojection, beta:  242.2
# backprojection, beta:  242.3
# backprojection, beta:  242.5
# backprojection, beta:  243.1
# backprojection, beta:  243.2
# backprojection, beta:  243.4
# backprojection, beta:  244.0
# backprojection, beta:  244.1
# backprojection, beta:  244.3
# backprojection, beta:  244.9
# backprojection, beta:  245.0
# backprojection, beta:  245.3
# backprojection, beta:  245.8
# backprojection, beta:  245.9
# backprojection, beta:  246.2
# backprojection, beta:  246.7
# backprojection, beta:  246.8
# backprojection, beta:  247.1
# backprojection, beta:  247.6
# backprojection, beta:  247.7
# backprojection, beta:  248.0
# backprojection, beta:  248.5
# backprojection, beta:  248.7
# backprojection, beta:  248.9
# backprojection, beta:  249.4
# backprojection, beta:  249.6
# backprojection, beta:  249.8
# backprojection, beta:  250.3
# backprojection, beta:  250.5
# backprojection, beta:  250.7
# backprojection, beta:  251.3
# backprojection, beta:  251.4
# backprojection, beta:  251.6
# backprojection, beta:  252.2
# backprojection, beta:  252.3
# backprojection, beta:  252.5
# backprojection, beta:  253.1
# backprojection, beta:  253.2
# backprojection, beta:  253.4
# backprojection, beta:  254.0
# backprojection, beta:  254.1
# backprojection, beta:  254.4
# backprojection, beta:  254.9
# backprojection, beta:  255.0
# backprojection, beta:  255.3
# backprojection, beta:  255.8
# backprojection, beta:  255.9
# backprojection, beta:  256.2
# backprojection, beta:  256.7
# backprojection, beta:  256.8
# backprojection, beta:  257.1
# backprojection, beta:  257.6
# backprojection, beta:  257.7
# backprojection, beta:  258.0
# backprojection, beta:  258.5
# backprojection, beta:  258.7
# backprojection, beta:  258.9
# backprojection, beta:  259.4
# backprojection, beta:  259.6
# backprojection, beta:  259.8
# backprojection, beta:  260.3
# backprojection, beta:  260.5
# backprojection, beta:  260.7
# backprojection, beta:  261.2
# backprojection, beta:  261.4
# backprojection, beta:  261.6
# backprojection, beta:  262.2
# backprojection, beta:  262.3
# backprojection, beta:  262.5
# backprojection, beta:  263.1
# backprojection, beta:  263.2
# backprojection, beta:  263.4
# backprojection, beta:  264.0
# backprojection, beta:  264.1
# backprojection, beta:  264.4
# backprojection, beta:  264.9
# backprojection, beta:  265.0
# backprojection, beta:  265.3
# backprojection, beta:  265.8
# backprojection, beta:  265.9
# backprojection, beta:  266.2
# backprojection, beta:  266.7
# backprojection, beta:  266.8
# backprojection, beta:  267.1
# backprojection, beta:  267.6
# backprojection, beta:  267.7
# backprojection, beta:  268.0
# backprojection, beta:  268.5
# backprojection, beta:  268.7
# backprojection, beta:  268.9
# backprojection, beta:  269.4
# backprojection, beta:  269.6
# backprojection, beta:  269.8
# backprojection, beta:  270.3
# backprojection, beta:  270.5
# backprojection, beta:  270.7
# backprojection, beta:  271.2
# backprojection, beta:  271.4
# backprojection, beta:  271.6
# backprojection, beta:  272.1
# backprojection, beta:  272.3
# backprojection, beta:  272.5
# backprojection, beta:  272.5
# backprojection, beta:  273.1
# backprojection, beta:  273.1
# backprojection, beta:  273.2
# backprojection, beta:  273.2
# backprojection, beta:  274.4
# backprojection, beta:  274.9
# backprojection, beta:  275.0
# backprojection, beta:  275.3
# backprojection, beta:  275.8
# backprojection, beta:  275.9
# backprojection, beta:  276.2
# backprojection, beta:  276.7
# backprojection, beta:  276.8
# backprojection, beta:  277.1
# backprojection, beta:  277.6
# backprojection, beta:  277.7
# backprojection, beta:  278.0
# backprojection, beta:  278.5
# backprojection, beta:  278.7
# backprojection, beta:  278.9
# backprojection, beta:  279.4
# backprojection, beta:  279.6
# backprojection, beta:  279.8
# backprojection, beta:  280.3
# backprojection, beta:  280.5
# backprojection, beta:  280.7
# backprojection, beta:  281.2
# backprojection, beta:  281.4
# backprojection, beta:  281.6
# backprojection, beta:  282.2
# backprojection, beta:  282.3
# backprojection, beta:  282.5
# backprojection, beta:  283.1
# backprojection, beta:  283.2
# backprojection, beta:  283.4
# backprojection, beta:  284.0
# backprojection, beta:  284.1
# backprojection, beta:  284.4
# backprojection, beta:  284.9
# backprojection, beta:  285.0
# backprojection, beta:  285.3
# backprojection, beta:  285.8
# backprojection, beta:  285.9
# backprojection, beta:  286.2
# backprojection, beta:  286.7
# backprojection, beta:  286.8
# backprojection, beta:  287.1
# backprojection, beta:  287.6
# backprojection, beta:  287.7
# backprojection, beta:  288.0
# backprojection, beta:  288.5
# backprojection, beta:  288.7
# backprojection, beta:  288.9
# backprojection, beta:  289.4
# backprojection, beta:  289.6
# backprojection, beta:  289.8
# backprojection, beta:  290.3
# backprojection, beta:  290.5
# backprojection, beta:  290.7
# backprojection, beta:  291.2
# backprojection, beta:  291.4
# backprojection, beta:  291.6
# backprojection, beta:  292.2
# backprojection, beta:  292.3
# backprojection, beta:  292.5
# backprojection, beta:  293.1
# backprojection, beta:  293.2
# backprojection, beta:  293.4
# backprojection, beta:  294.0
# backprojection, beta:  294.1
# backprojection, beta:  294.4
# backprojection, beta:  294.9
# backprojection, beta:  295.0
# backprojection, beta:  295.3
# backprojection, beta:  295.8
# backprojection, beta:  295.9
# backprojection, beta:  296.2
# backprojection, beta:  296.7
# backprojection, beta:  296.8
# backprojection, beta:  297.1
# backprojection, beta:  297.6
# backprojection, beta:  297.7
# backprojection, beta:  298.0
# backprojection, beta:  298.5
# backprojection, beta:  298.7
# backprojection, beta:  298.9
# backprojection, beta:  299.4
# backprojection, beta:  299.6
# backprojection, beta:  299.8
# backprojection, beta:  300.3
# backprojection, beta:  300.5
# backprojection, beta:  300.7
# backprojection, beta:  301.3
# backprojection, beta:  301.4
# backprojection, beta:  301.6
# backprojection, beta:  302.2
# backprojection, beta:  302.3
# backprojection, beta:  302.5
# backprojection, beta:  303.1
# backprojection, beta:  303.2
# backprojection, beta:  303.5
# backprojection, beta:  304.0
# backprojection, beta:  304.1
# backprojection, beta:  304.4
# backprojection, beta:  304.9
# backprojection, beta:  305.0
# backprojection, beta:  305.3
# backprojection, beta:  305.8
# backprojection, beta:  305.9
# backprojection, beta:  306.2
# backprojection, beta:  306.7
# backprojection, beta:  306.8
# backprojection, beta:  307.1
# backprojection, beta:  307.6
# backprojection, beta:  307.8
# backprojection, beta:  308.0
# backprojection, beta:  308.5
# backprojection, beta:  308.7
# backprojection, beta:  308.9
# backprojection, beta:  309.4
# backprojection, beta:  309.6
# backprojection, beta:  309.8
# backprojection, beta:  310.4
# backprojection, beta:  310.5
# backprojection, beta:  310.7
# backprojection, beta:  311.3
# backprojection, beta:  311.4
# backprojection, beta:  311.6
# backprojection, beta:  312.2
# backprojection, beta:  312.3
# backprojection, beta:  312.5
# backprojection, beta:  313.1
# backprojection, beta:  313.2
# backprojection, beta:  313.5
# backprojection, beta:  314.0
# backprojection, beta:  314.1
# backprojection, beta:  314.4
# backprojection, beta:  314.9
# backprojection, beta:  315.0
# backprojection, beta:  315.3
# backprojection, beta:  315.8
# backprojection, beta:  315.9
# backprojection, beta:  316.2
# backprojection, beta:  316.7
# backprojection, beta:  316.9
# backprojection, beta:  317.1
# backprojection, beta:  317.6
# backprojection, beta:  317.8
# backprojection, beta:  318.0
# backprojection, beta:  318.5
# backprojection, beta:  318.7
# backprojection, beta:  318.9
# backprojection, beta:  319.5
# backprojection, beta:  319.6
# backprojection, beta:  319.8
# backprojection, beta:  320.4
# backprojection, beta:  320.5
# backprojection, beta:  320.7
# backprojection, beta:  321.3
# backprojection, beta:  321.4
# backprojection, beta:  321.6
# backprojection, beta:  322.2
# backprojection, beta:  322.3
# backprojection, beta:  322.5
# backprojection, beta:  323.1
# backprojection, beta:  323.2
# backprojection, beta:  323.5
# backprojection, beta:  324.0
# backprojection, beta:  324.1
# backprojection, beta:  324.4
# backprojection, beta:  324.9
# backprojection, beta:  325.0
# backprojection, beta:  325.3
# backprojection, beta:  325.8
# backprojection, beta:  325.9
# backprojection, beta:  326.2
# backprojection, beta:  326.7
# backprojection, beta:  326.9
# backprojection, beta:  327.1
# backprojection, beta:  327.6
# backprojection, beta:  327.8
# backprojection, beta:  328.0
# backprojection, beta:  328.5
# backprojection, beta:  328.7
# backprojection, beta:  328.9
# backprojection, beta:  329.4
# backprojection, beta:  329.6
# backprojection, beta:  329.8
# backprojection, beta:  330.4
# backprojection, beta:  330.5
# backprojection, beta:  330.7
# backprojection, beta:  331.3
# backprojection, beta:  331.4
# backprojection, beta:  331.6
# backprojection, beta:  332.2
# backprojection, beta:  332.3
# backprojection, beta:  332.6
# backprojection, beta:  333.1
# backprojection, beta:  333.2
# backprojection, beta:  333.5
# backprojection, beta:  334.0
# backprojection, beta:  334.1
# backprojection, beta:  334.4
# backprojection, beta:  334.9
# backprojection, beta:  335.0
# backprojection, beta:  335.3
# backprojection, beta:  335.8
# backprojection, beta:  336.0
# backprojection, beta:  336.2
# backprojection, beta:  336.7
# backprojection, beta:  336.9
# backprojection, beta:  337.1
# backprojection, beta:  337.6
# backprojection, beta:  337.8
# backprojection, beta:  338.0
# backprojection, beta:  338.5
# backprojection, beta:  338.7
# backprojection, beta:  338.9
# backprojection, beta:  339.5
# backprojection, beta:  339.6
# backprojection, beta:  339.8
# backprojection, beta:  340.4
# backprojection, beta:  340.5
# backprojection, beta:  340.7
# backprojection, beta:  341.3
# backprojection, beta:  341.4
# backprojection, beta:  341.7
# backprojection, beta:  342.2
# backprojection, beta:  342.3
# backprojection, beta:  342.6
# backprojection, beta:  343.1
# backprojection, beta:  343.2
# backprojection, beta:  343.5
# backprojection, beta:  344.0
# backprojection, beta:  344.1
# backprojection, beta:  344.4
# backprojection, beta:  344.9
# backprojection, beta:  345.1
# backprojection, beta:  345.3
# backprojection, beta:  345.8
# backprojection, beta:  346.0
# backprojection, beta:  346.2
# backprojection, beta:  346.7
# backprojection, beta:  346.9
# backprojection, beta:  347.1
# backprojection, beta:  347.6
# backprojection, beta:  347.8
# backprojection, beta:  348.0
# backprojection, beta:  348.6
# backprojection, beta:  348.7
# backprojection, beta:  348.9
# backprojection, beta:  349.5
# backprojection, beta:  349.6
# backprojection, beta:  349.8
# backprojection, beta:  350.4
# backprojection, beta:  350.5
# backprojection, beta:  350.8
# backprojection, beta:  351.3
# backprojection, beta:  351.4
# backprojection, beta:  351.7
# backprojection, beta:  352.2
# backprojection, beta:  352.3
# backprojection, beta:  352.6
# backprojection, beta:  353.1
# backprojection, beta:  353.2
# backprojection, beta:  353.5
# backprojection, beta:  354.0
# backprojection, beta:  354.2
# backprojection, beta:  354.4
# backprojection, beta:  354.9
# backprojection, beta:  355.1
# backprojection, beta:  355.3
# backprojection, beta:  355.8
# backprojection, beta:  356.0
# backprojection, beta:  356.2
# backprojection, beta:  356.7
# backprojection, beta:  356.9
# backprojection, beta:  357.1
# backprojection, beta:  357.7
# backprojection, beta:  357.8
# backprojection, beta:  358.0
# backprojection, beta:  358.6
# backprojection, beta:  358.7
# backprojection, beta:  358.9
# backprojection, beta:  359.5
# backprojection, beta:  359.6
# backprojection, beta:  359.9

# %%
NimageZ=Nimage*sorted_images.shape[0]/sorted_images.shape[0]
Z_c=int(NimageZ/2.0)
X_c=int(Nimage/2.0)
Y_c=int(Nimage/2.0)
figure, axis=plt.subplots(1, 3,figsize=(12,12))
axis[0].imshow(rec_image[X_c,:,:].T, cmap='CMRmap_r')
axis[0].set_title('cross section at X=0')
axis[0].axis('off')
axis[1].imshow(rec_image[:,Y_c,:].T, cmap='CMRmap_r')
axis[1].set_title('cross section at Y=0')
axis[1].axis('off')
axis[2].imshow(rec_image[:,:,Z_c].T, cmap='CMRmap_r')
axis[2].set_title('cross section at Z=0')
axis[2].axis('off')
# plt.savefig(directory+"rec_image.pdf",format='pdf',dpi=250)
plt.show()

# %%
_TPS_pth = r"C:\Users\Pintu\OneDrive - Christian Medical College\Fabricated Phantom Rotational RT\RT Dose and Plan\Rotational Arc_Fabricated Phantom CT plans\RD.23022024.3ARCs.dcm"

tps_dcm = dcmread(_TPS_pth)
tps_image = tps_dcm.pixel_array

# %%
rec_image = np.transpose(rec_image, (2, 1, 0))

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# First row
fig.suptitle('3D Dose calculation 3Arc', fontsize=16)
fig.subplots_adjust(top=0.9)  # Adjust the top to make room for the main title

# First row
axs[0,0].imshow(rec_image[X_c,:,:].T, cmap='CMRmap_r')
axs[0,0].set_title('cross section at X=0')
axs[0,0].axis('off')
axs[0,1].imshow(rec_image[:,Y_c,:].T, cmap='CMRmap_r')
axs[0,1].set_title('cross section at Y=0')
axs[0,1].axis('off')
axs[0,2].imshow(rec_image[:,:,Z_c].T, cmap='CMRmap_r')
axs[0,2].set_title('cross section at Z=0')
axs[0,2].axis('off')
fig.text(0.5, 0.93, 'EPID Dose reconstruction', ha='center', va='center', fontsize=14)

# Second row
axs[1, 0].imshow(tps_image[X_c,:,:].T, cmap='CMRmap_r')
axs[1, 0].set_title('cross section at X=0')
axs[1, 0].axis('off')
axs[1, 1].imshow(tps_image[:,Y_c,:].T, cmap='CMRmap_r')
axs[1, 1].set_title('cross section at Y=0')
axs[1, 1].axis('off')
axs[1, 2].imshow(tps_image[:,:,Z_c].T, cmap='CMRmap_r')
axs[1, 2].set_title('cross section at Z=0')
axs[1, 2].axis('off')
fig.text(0.5, 0.5, 'TPS Dose', ha='center', va='center', fontsize=14)

plt.show()

# %%
scaler = np.max(tps_dcm.pixel_array)/np.max(rec_image)

# %%
write_image = np.int32(rec_image*scaler)

# %%
write_dicom = tps_dcm.copy()
# write_dicom.PixelData

# %%
write_dicom.PixelData = np.int32(rec_image).tobytes()

# %%
dcmwrite(r"D:\CMC\pyprojects\radio_therapy\dose-3d\dataset\3DDose\EPID RD.23022024.12 x 12.dcm", write_dicom)
